# %%
pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize
from collections import Counter
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def unigram(text):
    tokens = word_tokenize(text.lower())
    unigrams = Counter(tokens)
    return unigrams
text = """Massive landslides hit the district of Wayanad in northern Kerala
 in the early hours of July 30, with continuous torrential rainfall triggering
  large-scale death and destruction in Mundakkai and Chooralmala of Meppadi panchayat,
   with entire villages being washed away."""
unigram_data = unigram(text)
print(unigram_data)
# Out:
# Counter({'of': 3, 'in': 3, 'the': 2, ',': 2, 'with': 2, 'and': 2, 'massive': 1, 'landslides': 1, 'hit': 1, 'district': 1, 'wayanad': 1, 'northern': 1, 'kerala': 1, 'early': 1, 'hours': 1, 'july': 1, '30': 1, 'continuous': 1, 'torrential': 1, 'rainfall': 1, 'triggering': 1, 'large-scale': 1, 'death': 1, 'destruction': 1, 'mundakkai': 1, 'chooralmala': 1, 'meppadi': 1, 'panchayat': 1, 'entire': 1, 'villages': 1, 'being': 1, 'washed': 1, 'away': 1, '.': 1})
