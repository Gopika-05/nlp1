# %%
import nltk
from nltk import ngrams
from collections import Counter
nltk.download('punkt')
text = """Massive landslides hit the district of Wayanad in northern Kerala
 in the early hours of July 30, with continuous torrential rainfall triggering large-scale
 death and destruction in Mundakkai and Chooralmala of Meppadi panchayat, with entire villages being washed away."""
tokens = nltk.word_tokenize(text)
bigrams = list(ngrams(tokens, 2))
bigram_freq = Counter(bigrams)
word_freq = Counter(tokens)
bigram_probabilities = {}
for (w1, w2), count in bigram_freq.items():
    prob = count / word_freq[w1]
    bigram_probabilities[(w1, w2)] = prob
for bigram, prob in bigram_probabilities.items():
    print(f"P({bigram[1]} | {bigram[0]}) = {prob:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# P(landslides | Massive) = 1.0000
# P(hit | landslides) = 1.0000
# P(the | hit) = 1.0000
# P(district | the) = 0.5000
# P(of | district) = 1.0000
# P(Wayanad | of) = 0.3333
# P(in | Wayanad) = 1.0000
# P(northern | in) = 0.3333
# P(Kerala | northern) = 1.0000
# P(in | Kerala) = 1.0000
# P(the | in) = 0.3333
# P(early | the) = 0.5000
# P(hours | early) = 1.0000
# P(of | hours) = 1.0000
# P(July | of) = 0.3333
# P(30 | July) = 1.0000
# P(, | 30) = 1.0000
# P(with | ,) = 1.0000
# P(continuous | with) = 0.5000
# P(torrential | continuous) = 1.0000
# P(rainfall | torrential) = 1.0000
# P(triggering | rainfall) = 1.0000
# P(large-scale | triggering) = 1.0000
# P(death | large-scale) = 1.0000
# P(and | death) = 1.0000
# P(destruction | and) = 0.5000
# P(in | destruction) = 1.0000
# P(Mundakkai | in) = 0.3333
# P(and | Mundakkai) = 1.0000
# P(Chooralmala | and) = 0.5000
# ...
